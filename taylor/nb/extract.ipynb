# %%
import pandas as pd
import json
import os
import matplotlib.pyplot as plt

# Ensure the 'output' folder exists
output_dir = 'output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
file = 'dockets-2023-07-31.csv'

# %%
df2 = pd.read_csv(file, skiprows=1, nrows=5)
df2
# Out:
#          id                   date_created                  date_modified  \
# 0  64708104  2022-07-29 21:03:07.837618+00  2023-07-30 12:34:02.767537+00
# 1  67156114  2023-04-07 17:19:22.103032+00  2023-04-07 17:19:22.103045+00
# 2  67156115  2023-04-07 17:19:22.103146+00  2023-04-07 17:19:22.103151+00
# 3   4934766  2017-04-20 16:41:20.515153+00  2021-11-05 23:01:30.395536+00
# 4  67305164  2023-05-01 20:02:28.437322+00       2023-06-26 20:35:08.7+00
#
#    source  appeal_from_str  assigned_to_str  referred_to_str  panel_str  \
# 0       1              NaN  Christina Reiss              NaN        NaN
# 1       1              NaN              NaN              NaN        NaN
# 2       1              NaN              NaN              NaN        NaN
# 3       1              NaN              NaN              NaN        NaN
# 4       1              NaN              NaN              NaN        NaN
#
#                  date_last_index  date_cert_granted  ...  \
# ...

# %%
def count_lines_in_csv(file_path):
    line_count = 0
    try:
        with open(file_path, 'r') as file:
            for line in file:
                line_count += 1
        return line_count
    except FileNotFoundError:
        return "File not found."
    except Exception as e:
        return f"An error occurred: {e}"

# Example usage:
# file_path = "path/to/your/csv/file.csv"
# print(count_lines_in_csv(file_path))

# %%
file_path = file
print(count_lines_in_csv(file_path))
# Out:
# 66068139

# %%
import json
import os
import pandas as pd

# Create a directory to store output JSON files
output_dir = 'output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Skip the first row and read the next 10 rows of the CSV file, using the second row as the header
df = pd.read_csv(file, skiprows=1, nrows=10)

# Iterate through each row to save it as a JSON file
for index, row in df.iterrows():
    row_dict = row.to_dict()
    
    # Get the 'id' field value
    row_id = row_dict.get('id', f'row_{index}')  # Default to 'row_{index}' if 'id' is not found
    
    output_filename = os.path.join(output_dir, f'{row_id}.json')
    with open(output_filename, 'w') as json_file:
        json.dump(row_dict, json_file, indent=4)

print("First 10 rows have been successfully saved as JSON files.")
# Out:
# First 10 rows have been successfully saved as JSON files.

# %%
import json
import os
import pandas as pd

# Create a directory to store output JSON files
output_dir = 'output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Read the CSV file in chunks
chunksize = 50000  # Number of rows to read at each iteration
for chunk in pd.read_csv(file, skiprows=1, chunksize=chunksize):
    
    # Iterate through each row in the current chunk to save it as a JSON file
    for index, row in chunk.iterrows():
        row_dict = row.to_dict()
        
        # Get the 'id' field value
        row_id = row_dict.get('id', f'row_{index}')  # Default to 'row_{index}' if 'id' is not found
        
        output_filename = os.path.join(output_dir, f'{row_id}.json')
        with open(output_filename, 'w') as json_file:
            json.dump(row_dict, json_file, indent=4)

print("All rows have been successfully saved as JSON files.")
# Out:
# /var/folders/v0/cvs3s56j6nnc5wpthwy35v2r0000gn/T/ipykernel_59546/3303273648.py:12: DtypeWarning: Columns (4,7,11,19,28,29,30,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(file, skiprows=1, chunksize=chunksize):
# /var/folders/v0/cvs3s56j6nnc5wpthwy35v2r0000gn/T/ipykernel_59546/3303273648.py:12: DtypeWarning: Columns (7,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(file, skiprows=1, chunksize=chunksize):
# /var/folders/v0/cvs3s56j6nnc5wpthwy35v2r0000gn/T/ipykernel_59546/3303273648.py:12: DtypeWarning: Columns (4,7,11,19,28,29,30,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   for chunk in pd.read_csv(file, skiprows=1, chunksize=chunksize):
# ...
